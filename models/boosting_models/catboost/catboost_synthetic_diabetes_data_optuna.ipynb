# %%
import pandas as pd
import numpy as np
import catboost as cb
import optuna

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_squared_error as mse

# %%
df = pd.read_csv('../../../datasets/synthesized_diabetes_data.csv')

# %%
df.head()
# Out:
#    Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0       1        1    1.015491          0              0               60
# 1       1        1    2.793550          1              2              299
# 2       0        0    1.020575          0              1              497
# 3       1        1    0.967628          0              0               35
# 4       1        1    1.929354          0              0              340
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0        2263.426739  120.264574        362.034926        0.999618
# 1         207.078743   97.333547        185.855127        0.994450
# 2        -222.105153   98.957504        361.411489        0.999132
# 3        1874.200797  141.121981        360.427013        0.999273
# 4          47.080906  322.936778        360.013915        0.979882
#
#    Property_Area  Loan_Status
# 0              2            1
# 1              1            1
# 2              0            1
# 3              2            1
# 4              0            1

# %%
df.columns
# Out:
# Index(['Gender', 'Married', 'Dependents', 'Education', 'Self_Employed',
#        'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
x = df.drop(columns=['Loan_Status'])
y = df['Loan_Status']

# %%
x
# Out:
#       Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0          1        1    1.015491          0              0               60
# 1          1        1    2.793550          1              2              299
# 2          0        0    1.020575          0              1              497
# 3          1        1    0.967628          0              0               35
# 4          1        1    1.929354          0              0              340
# ...      ...      ...         ...        ...            ...              ...
# 3995       1        1    2.118012          0              0              248
# 3996       0        0   -0.002574          0              0              249
# 3997       1        1    0.010152          0              0              300
# 3998       0        1   -0.002625          0              0              385
# 3999       1        1    0.007271          0              0              462
#
#       CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0           2263.426739  120.264574        362.034926        0.999618
# 1            207.078743   97.333547        185.855127        0.994450
# 2           -222.105153   98.957504        361.411489        0.999132
# 3           1874.200797  141.121981        360.427013        0.999273
# 4             47.080906  322.936778        360.013915        0.979882
# ...                 ...         ...               ...             ...
# 3995        2693.049737  176.172212        360.665439        1.007047
# 3996        1949.728061  117.277610        361.044262        0.986177
# 3997        2882.202092  136.098872        361.722296        0.994603
# 3998         182.631094  191.733185        360.723093        0.989029
# 3999        2590.286571  119.756303        360.276315        0.997789
#
#       Property_Area
# 0                 2
# 1                 1
# 2                 0
# 3                 2
# 4                 0
# ...             ...
# 3995              1
# 3996              1
# 3997              0
# 3998              1
# 3999              1
#
# [4000 rows x 11 columns]

# %%
y
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 3995    1
# 3996    1
# 3997    1
# 3998    0
# 3999    1
# Name: Loan_Status, Length: 4000, dtype: int64

# %%
def objective(trial):
    x_train, x_validate, y_train, y_validate = train_test_split(x, y, test_size=0.3)
    
    param = {
        'objective': trial.suggest_categorical('objective', ['Logloss', 'CrossEntropy']),
        'colsample_bylevel': trial.suggest_float('colsample_bylevel', 0.01, 0.1),
        'depth' : trial.suggest_int('depth', 1, 12),
        'boosting_type' : trial.suggest_categorical('boosting_type', ['Ordered', 'Plain']),
        'bootstrap_type' : trial.suggest_categorical('bootstrap_type', ['Bayesian', 'Bernoulli', 'MVS']),
        'used_ram_limit' : '3gb',
    }
    
    if param['bootstrap_type'] == 'Bayesian': param['bagging_temperature'] = trial.suggest_float('bagging_temperature', 0, 10)
    
    elif param['bootstrap_type'] == 'Bernoulli' : param['subsample'] = trial.suggest_float('subsample', 0.1, 1)
    
    gbm = cb.CatBoostClassifier(**param)
    
    gbm.fit(x_train, y_train, eval_set=[(x_validate, y_validate)], verbose=0, early_stopping_rounds=100)
    
    preds = gbm.predict(x_validate)
    pred_labels = np.rint(preds)
    accuracy = accuracy_score(y_validate, pred_labels)
    
    return accuracy

# %%
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=50, timeout=600)
# Out:
# [I 2022-05-04 11:27:06,185] A new study created in memory with name: no-name-49ca012b-df35-4c24-9c29-2dea1075882f
# [I 2022-05-04 11:27:18,964] Trial 0 finished with value: 0.9091666666666667 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.0981800722269784, 'depth': 1, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'subsample': 0.14349183693663986}. Best is trial 0 with value: 0.9091666666666667.
# [I 2022-05-04 11:27:29,602] Trial 1 finished with value: 0.9183333333333333 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.027894970249399735, 'depth': 1, 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS'}. Best is trial 1 with value: 0.9183333333333333.
# [I 2022-05-04 11:27:48,996] Trial 2 finished with value: 0.9158333333333334 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.09666931727361973, 'depth': 12, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'subsample': 0.3132039103795732}. Best is trial 1 with value: 0.9183333333333333.
# [I 2022-05-04 11:27:51,779] Trial 3 finished with value: 0.9258333333333333 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.03848563697599416, 'depth': 12, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 4.8396699920023}. Best is trial 3 with value: 0.9258333333333333.
# [I 2022-05-04 11:28:06,895] Trial 4 finished with value: 0.92 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.07604228908342987, 'depth': 6, 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS'}. Best is trial 3 with value: 0.9258333333333333.
# [I 2022-05-04 11:28:18,558] Trial 5 finished with value: 0.9158333333333334 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.04788019930972476, 'depth': 11, 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS'}. Best is trial 3 with value: 0.9258333333333333.
# [I 2022-05-04 11:28:30,021] Trial 6 finished with value: 0.9233333333333333 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.08756377469048264, 'depth': 1, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 2.8557824573747626}. Best is trial 3 with value: 0.9258333333333333.
# [I 2022-05-04 11:28:40,671] Trial 7 finished with value: 0.9108333333333334 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.022552658960830918, 'depth': 9, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'subsample': 0.38066792181521203}. Best is trial 3 with value: 0.9258333333333333.
# [I 2022-05-04 11:28:44,167] Trial 8 finished with value: 0.9216666666666666 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.08045169692516146, 'depth': 10, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 2.772664740536268}. Best is trial 3 with value: 0.9258333333333333.
# [I 2022-05-04 11:28:46,993] Trial 9 finished with value: 0.9033333333333333 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.018506243221140917, 'depth': 6, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 3 with value: 0.9258333333333333.
# [I 2022-05-04 11:28:50,898] Trial 10 finished with value: 0.9158333333333334 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.04986588777022244, 'depth': 8, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 8.926220756412306}. Best is trial 3 with value: 0.9258333333333333.
# [I 2022-05-04 11:28:54,207] Trial 11 finished with value: 0.9166666666666666 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.06752209787687656, 'depth': 4, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 3.726212874435218}. Best is trial 3 with value: 0.9258333333333333.
# [I 2022-05-04 11:28:57,259] Trial 12 finished with value: 0.94 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.03667750306928356, 'depth': 4, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 0.479403316898928}. Best is trial 12 with value: 0.94.
# [I 2022-05-04 11:29:01,208] Trial 13 finished with value: 0.9175 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.0380949518086141, 'depth': 4, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 0.6785884318275369}. Best is trial 12 with value: 0.94.
# [I 2022-05-04 11:29:04,166] Trial 14 finished with value: 0.9183333333333333 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.03608705825296574, 'depth': 4, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 7.206300700178471}. Best is trial 12 with value: 0.94.
# [I 2022-05-04 11:29:08,586] Trial 15 finished with value: 0.9216666666666666 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.06325326075314631, 'depth': 7, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 0.0442999192534404}. Best is trial 12 with value: 0.94.
# [I 2022-05-04 11:29:11,502] Trial 16 finished with value: 0.915 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.037441474009418364, 'depth': 3, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 5.822430648323085}. Best is trial 12 with value: 0.94.
# [I 2022-05-04 11:29:14,691] Trial 17 finished with value: 0.8691666666666666 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.013399457052990185, 'depth': 12, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 5.929553416781807}. Best is trial 12 with value: 0.94.
# [I 2022-05-04 11:29:18,739] Trial 18 finished with value: 0.9283333333333333 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.05747667730958876, 'depth': 8, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 1.7023592116051178}. Best is trial 12 with value: 0.94.
# [I 2022-05-04 11:29:22,816] Trial 19 finished with value: 0.9225 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.059384482272113126, 'depth': 7, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.9941388546520065}. Best is trial 12 with value: 0.94.
# [I 2022-05-04 11:29:26,401] Trial 20 finished with value: 0.925 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.05296411351260588, 'depth': 5, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 1.1623594913922914}. Best is trial 12 with value: 0.94.
# [I 2022-05-04 11:29:30,058] Trial 21 finished with value: 0.9258333333333333 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.041273773261864106, 'depth': 9, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 2.0789486609854357}. Best is trial 12 with value: 0.94.
# [I 2022-05-04 11:29:33,794] Trial 22 finished with value: 0.9158333333333334 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.04481434723053613, 'depth': 9, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 1.791089952790479}. Best is trial 12 with value: 0.94.
# [I 2022-05-04 11:29:36,742] Trial 23 finished with value: 0.9108333333333334 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.02850991379420481, 'depth': 3, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 4.476639434664058}. Best is trial 12 with value: 0.94.
# [I 2022-05-04 11:29:41,203] Trial 24 finished with value: 0.9075 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.0685677521242131, 'depth': 8, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 2.1392603550155758}. Best is trial 12 with value: 0.94.
# [I 2022-05-04 11:29:44,335] Trial 25 finished with value: 0.9358333333333333 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.0563692407754452, 'depth': 10, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 0.18511138463102644}. Best is trial 12 with value: 0.94.
# [I 2022-05-04 11:29:47,403] Trial 26 finished with value: 0.9233333333333333 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.060618336545108356, 'depth': 10, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 0.06302591384024313}. Best is trial 12 with value: 0.94.
# [I 2022-05-04 11:29:51,369] Trial 27 finished with value: 0.9208333333333333 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.05532597467520224, 'depth': 8, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 1.124073863373744}. Best is trial 12 with value: 0.94.
# [I 2022-05-04 11:29:54,209] Trial 28 finished with value: 0.9175 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.029290791686145273, 'depth': 10, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.8489185714938778}. Best is trial 12 with value: 0.94.
# [I 2022-05-04 11:29:57,426] Trial 29 finished with value: 0.9241666666666667 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.0710881459268671, 'depth': 2, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 12 with value: 0.94.
# [I 2022-05-04 11:30:00,514] Trial 30 finished with value: 0.9275 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.056168974970775824, 'depth': 5, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.6748479523859836}. Best is trial 12 with value: 0.94.
# [I 2022-05-04 11:30:03,693] Trial 31 finished with value: 0.9266666666666666 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.05629788880840361, 'depth': 5, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.6247464930183985}. Best is trial 12 with value: 0.94.
# [I 2022-05-04 11:30:06,758] Trial 32 finished with value: 0.9266666666666666 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.045995725202401874, 'depth': 5, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.6577130762737146}. Best is trial 12 with value: 0.94.
# [I 2022-05-04 11:30:09,964] Trial 33 finished with value: 0.9366666666666666 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.05290580052401506, 'depth': 6, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.769833548282534}. Best is trial 12 with value: 0.94.
# [I 2022-05-04 11:30:23,839] Trial 34 finished with value: 0.9291666666666667 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.06339779258238594, 'depth': 7, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'subsample': 0.8436317246881603}. Best is trial 12 with value: 0.94.
# [I 2022-05-04 11:30:37,574] Trial 35 finished with value: 0.9291666666666667 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.06420330023748003, 'depth': 6, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'subsample': 0.8345911796291309}. Best is trial 12 with value: 0.94.
# [I 2022-05-04 11:30:48,679] Trial 36 finished with value: 0.9241666666666667 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.0750103429583528, 'depth': 6, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'subsample': 0.829810315372553}. Best is trial 12 with value: 0.94.
# [I 2022-05-04 11:31:04,495] Trial 37 finished with value: 0.9333333333333333 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.09953862824855819, 'depth': 7, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'subsample': 0.9660932790712452}. Best is trial 12 with value: 0.94.
# [I 2022-05-04 11:31:17,455] Trial 38 finished with value: 0.9391666666666667 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.09824547277783177, 'depth': 3, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'subsample': 0.9929470950687548}. Best is trial 12 with value: 0.94.
# [I 2022-05-04 11:31:31,018] Trial 39 finished with value: 0.9241666666666667 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.09254206671643296, 'depth': 2, 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS'}. Best is trial 12 with value: 0.94.
# [I 2022-05-04 11:31:43,584] Trial 40 finished with value: 0.9291666666666667 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.08380649696882024, 'depth': 3, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'subsample': 0.4687187216739721}. Best is trial 12 with value: 0.94.
# [I 2022-05-04 11:31:57,958] Trial 41 finished with value: 0.9216666666666666 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.09314169028417917, 'depth': 1, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'subsample': 0.9981668047096669}. Best is trial 12 with value: 0.94.
# [I 2022-05-04 11:32:10,157] Trial 42 finished with value: 0.9191666666666667 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.09911777798719275, 'depth': 2, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'subsample': 0.9320739118557836}. Best is trial 12 with value: 0.94.
# [I 2022-05-04 11:32:24,691] Trial 43 finished with value: 0.9233333333333333 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.08789612478877602, 'depth': 4, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'subsample': 0.7904409069033158}. Best is trial 12 with value: 0.94.
# [I 2022-05-04 11:32:39,426] Trial 44 finished with value: 0.9258333333333333 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.09385088697243371, 'depth': 11, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'subsample': 0.9365689449192309}. Best is trial 12 with value: 0.94.
# [I 2022-05-04 11:32:52,402] Trial 45 finished with value: 0.9133333333333333 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.03332089150903309, 'depth': 3, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'subsample': 0.7352100309333361}. Best is trial 12 with value: 0.94.
# [I 2022-05-04 11:33:03,261] Trial 46 finished with value: 0.8975 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.020803474187832457, 'depth': 11, 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS'}. Best is trial 12 with value: 0.94.
# [I 2022-05-04 11:33:17,691] Trial 47 finished with value: 0.9208333333333333 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.08147468928729976, 'depth': 4, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'subsample': 0.923343677438523}. Best is trial 12 with value: 0.94.
# [I 2022-05-04 11:33:32,970] Trial 48 finished with value: 0.9241666666666667 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.08824132287166045, 'depth': 5, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'subsample': 0.5246019302576805}. Best is trial 12 with value: 0.94.
# [I 2022-05-04 11:33:46,500] Trial 49 finished with value: 0.9208333333333333 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.05082182251669634, 'depth': 7, 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS'}. Best is trial 12 with value: 0.94.

# %%
print('NUmber of finshed trials: {}'.format(len(study.trials)))
print('Best trial:')

trial = study.best_trial

print(' Value: {}'.format(trial.value))

print(' Params: ')
for key, value in trial.params.items():
    print(' {}: {}'.format(key, value))
# Out:
# NUmber of finshed trials: 50
# Best trial:
#  Value: 0.94
#  Params:
#  objective: CrossEntropy
#  colsample_bylevel: 0.03667750306928356
#  depth: 4
#  boosting_type: Plain
#  bootstrap_type: Bayesian
#  bagging_temperature: 0.479403316898928

# %%
train_x, test_x, train_y, test_y = train_test_split(x, y, test_size=0.2, random_state=30)

# %%
cb_loan = cb.CatBoostClassifier(n_estimators=100,
                                objective='CrossEntropy',
                                colsample_bylevel=0.09,
                                depth=4,
                                boosting_type='Plain',
                                bootstrap_type='Bernoulli',
                                subsample=0.34,
                                loss_function='Logloss',
                                learning_rate=0.1,
                                task_type='CPU',
                                random_state=1,
                                verbose=False)

# %%
cb_loan.fit(train_x, train_y)

# %%
loan_predicted = cb_loan.predict(test_x)

# %%
model_rmse = np.sqrt(mse(test_y, loan_predicted))

# %%
model_rmse
# Out:
# 0.2936835031117683
