# %%
import pandas as pd
from catboost import CatBoostClassifier
import time
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error as mse
import numpy as np
from sklearn.model_selection import GridSearchCV

# %%
df = pd.read_csv('../../../datasets/synthesized_diabetes_data.csv')

# %%
df
# Out:
#             chol  stab.glu        hdl     ratio     glyhb  location  age  \
# 0     156.700394        31  52.154896  3.314927  4.299748         1    7
# 1     205.708528        50  74.558454  2.397619  4.750497         1   50
# 2     184.259740        39  50.107744  2.436952  5.033467         1   56
# 3     236.859522        40  46.163972  3.794523  5.382256         0   51
# 4     189.616025        92  40.045044  3.633247  4.634788         1   10
# ...          ...       ...        ...       ...       ...       ...  ...
# 6495  257.604430        98  35.771984  5.118372  4.753262         0   18
# 6496  162.296900        45  35.999784  5.681376  4.227569         1    4
# 6497  187.502574        57  33.007135  4.111922  5.364477         1   20
# 6498  182.580909        32  52.969260  2.549922  4.153793         1   16
# 6499  101.290703        94  28.458160  6.511101  8.391174         0   46
#
#       gender     height      weight  ...       bp.1d       bp.2s      bp.2d  \
# 0          1  68.496912  146.234609  ...   85.186571  151.973658  92.697071
# 1          0  67.514518  155.252176  ...   88.848128  152.708004  92.802874
# 2          0  63.226992  134.186382  ...   94.615906  153.064309  92.212116
# 3          0  66.799333  202.246191  ...   79.333852  151.949308  92.541618
# 4          1  69.283944  186.218617  ...   67.017735  151.475941  92.036697
# ...      ...        ...         ...  ...         ...         ...        ...
# 6495       0  61.331854  235.607829  ...  102.549858  152.100496  83.917625
# 6496       0  65.386967  296.862677  ...   84.701618  125.647137  82.484329
# 6497       0  66.676238  190.406558  ...   76.921248  151.736385  93.133092
# 6498       0  61.393461  132.810153  ...   66.361413  151.984054  92.246495
# 6499       1  65.889821  313.736387  ...  109.086086  140.006507  85.340720
#
#           waist        hip    time.ppn  height_meters         BMI  \
# 0     29.222653  34.012633  761.958003       1.667030   53.028606
# 1     32.887620  40.640470  715.021735       1.681850   42.542497
# 2     32.548504  36.741043  210.965098       1.565997   54.781513
# 3     45.726840  50.127763  801.800590       1.752456   65.815471
# 4     32.192694  41.216135  160.570897       1.779865   58.610103
# ...         ...        ...         ...            ...         ...
# 6495  35.150511  53.406133   88.264917       1.529035   68.481644
# 6496  39.052591  59.843454  443.647170       1.656517   80.007193
# 6497  49.009939  64.824856  187.248003       1.722115  115.404367
# 6498  31.932760  46.220675  895.800788       1.542742   65.397955
# 6499  49.858667  52.974802  157.157333       1.597931   77.849449
#
#       hip_waist_ratio  diabetic
# 0            0.815154         0
# 1            0.855346         1
# 2            0.863442         0
# 3            0.851003         1
# 4            0.890379         1
# ...               ...       ...
# 6495         0.855944         1
# 6496         0.830202         0
# 6497         0.820453         1
# 6498         0.777446         0
# 6499         0.920231         1
#
# [6500 rows x 22 columns]

# %%
x = df.drop(columns='diabetic', index=None)
y = df['diabetic']

# %%
y
# Out:
# 0       0
# 1       1
# 2       0
# 3       1
# 4       1
#        ..
# 6495    1
# 6496    0
# 6497    1
# 6498    0
# 6499    1
# Name: diabetic, Length: 6500, dtype: int64

# %%
x
# Out:
#             chol  stab.glu        hdl     ratio     glyhb  location  age  \
# 0     156.700394        31  52.154896  3.314927  4.299748         1    7
# 1     205.708528        50  74.558454  2.397619  4.750497         1   50
# 2     184.259740        39  50.107744  2.436952  5.033467         1   56
# 3     236.859522        40  46.163972  3.794523  5.382256         0   51
# 4     189.616025        92  40.045044  3.633247  4.634788         1   10
# ...          ...       ...        ...       ...       ...       ...  ...
# 6495  257.604430        98  35.771984  5.118372  4.753262         0   18
# 6496  162.296900        45  35.999784  5.681376  4.227569         1    4
# 6497  187.502574        57  33.007135  4.111922  5.364477         1   20
# 6498  182.580909        32  52.969260  2.549922  4.153793         1   16
# 6499  101.290703        94  28.458160  6.511101  8.391174         0   46
#
#       gender     height      weight  ...       bp.1s       bp.1d       bp.2s  \
# 0          1  68.496912  146.234609  ...  121.623985   85.186571  151.973658
# 1          0  67.514518  155.252176  ...  130.264602   88.848128  152.708004
# 2          0  63.226992  134.186382  ...  133.617710   94.615906  153.064309
# 3          0  66.799333  202.246191  ...  206.689504   79.333852  151.949308
# 4          1  69.283944  186.218617  ...  109.481572   67.017735  151.475941
# ...      ...        ...         ...  ...         ...         ...         ...
# 6495       0  61.331854  235.607829  ...  202.049036  102.549858  152.100496
# 6496       0  65.386967  296.862677  ...  121.976799   84.701618  125.647137
# 6497       0  66.676238  190.406558  ...  114.021723   76.921248  151.736385
# 6498       0  61.393461  132.810153  ...  106.366161   66.361413  151.984054
# 6499       1  65.889821  313.736387  ...  183.061726  109.086086  140.006507
#
#           bp.2d      waist        hip    time.ppn  height_meters         BMI  \
# 0     92.697071  29.222653  34.012633  761.958003       1.667030   53.028606
# 1     92.802874  32.887620  40.640470  715.021735       1.681850   42.542497
# 2     92.212116  32.548504  36.741043  210.965098       1.565997   54.781513
# 3     92.541618  45.726840  50.127763  801.800590       1.752456   65.815471
# 4     92.036697  32.192694  41.216135  160.570897       1.779865   58.610103
# ...         ...        ...        ...         ...            ...         ...
# 6495  83.917625  35.150511  53.406133   88.264917       1.529035   68.481644
# 6496  82.484329  39.052591  59.843454  443.647170       1.656517   80.007193
# 6497  93.133092  49.009939  64.824856  187.248003       1.722115  115.404367
# 6498  92.246495  31.932760  46.220675  895.800788       1.542742   65.397955
# 6499  85.340720  49.858667  52.974802  157.157333       1.597931   77.849449
#
#       hip_waist_ratio
# 0            0.815154
# 1            0.855346
# 2            0.863442
# 3            0.851003
# 4            0.890379
# ...               ...
# 6495         0.855944
# 6496         0.830202
# 6497         0.820453
# 6498         0.777446
# 6499         0.920231
#
# [6500 rows x 21 columns]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=30)

# %%
cb_diabetic = CatBoostClassifier(n_estimators=100,
                       loss_function='Logloss',
                       learning_rate=0.1,
                       depth=3, 
                        task_type='CPU',
                       random_state=1,
                       verbose=False)

# %%
cb_diabetic.fit(x_train, y_train)

# %%
loan_predicted = cb_diabetic.predict(x_test)

# %%
model_rmse = np.sqrt(mse(y_test, loan_predicted))

# %%
model_rmse
# Out:
# 0.31622776601683794

# %%
cb_loan_grid = CatBoostClassifier(n_estimators=100,
                       loss_function='Logloss',
                       learning_rate=0.1,
                        task_type='CPU',
                       random_state=1,
                       verbose=False)

# %%
grid_loan = {
    'max_depth' : [3, 4, 5],
    'n_estimators' : [100, 200, 300]
}

# %%
grid_cat = GridSearchCV(
    estimator = cb_loan_grid,
    param_grid= grid_loan,
    scoring= 'accuracy',
    cv = 5
)

# %%
grid_cat.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=<catboost.core.CatBoostClassifier object at 0x0000019674D491F0>,
#              param_grid={'max_depth': [3, 4, 5],
#                          'n_estimators': [100, 200, 300]},
#              scoring='accuracy')

# %%
loan_predicted = grid_cat.predict(x_test)

# %%
model_rmse_grid = np.sqrt(mse(y_test, loan_predicted))

# %%
model_rmse_grid
# Out:
# 0.30255323752764823

# %%
print(model_rmse)
print(model_rmse_grid)
# Out:
# 0.31622776601683794
# 0.30255323752764823
